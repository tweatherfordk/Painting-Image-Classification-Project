# %% [markdown]
# # Image Classification Notes

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython.display import Image

# %%
Image(filename = '/Users/weatherford/Downloads/archive (2)/dataset/dataset_updated/training_set/painting/2369.jpg')

# %%
cb_img = cv2.imread("/Users/weatherford/Downloads/archive (2)/dataset/dataset_updated/training_set/painting/2369.jpg",0)
cb_img
# Out:
# array([[33, 41, 46, ..., 38, 31, 31],
#        [32, 39, 42, ..., 34, 33, 33],
#        [32, 36, 38, ..., 29, 33, 33],
#        ...,
#        [53, 51, 46, ..., 59, 65, 66],
#        [54, 53, 50, ..., 68, 67, 67],
#        [54, 53, 51, ..., 75, 67, 66]], dtype=uint8)

# %%
plt.imshow(cb_img, cmap = 'gray');
